# %% [markdown]
# # Getting data using Selenium

# %%
#Importing all needed libraries
from selenium import webdriver
import time


import time
import requests
from pprint import pprint
from bs4 import BeautifulSoup
import pandas as pd

import json
from lxml import html
import re
import csv
import numpy as np

# %%
#Opening the browser and getting the url
browser = webdriver.Chrome()
url="https://www.youtube.com/feed/trending"
browser.get(url)
#wait 5 seconds to load
time=5
#

# %%
#getting trending video urls
urls=[i.get_attribute('href') for i in browser.find_elements_by_css_selector('a#video-title')] #<a> tag with video title id
urls
# Out:
# ['https://www.youtube.com/watch?v=MBPdKxlazD0',
#  'https://www.youtube.com/watch?v=w7pYhpJaJW8',
#  'https://www.youtube.com/watch?v=f3uVr2bZKUU',
#  'https://www.youtube.com/watch?v=tgBHu2D66Rg',
#  'https://www.youtube.com/watch?v=YUAIFQfgH_s',
#  'https://www.youtube.com/watch?v=9roJHCjU4kU',
#  'https://www.youtube.com/watch?v=imMjnPMEU1c',
#  'https://www.youtube.com/watch?v=y7xU_2Zzbb0',
#  'https://www.youtube.com/watch?v=jtthgYYhkz0',
#  'https://www.youtube.com/watch?v=PV9jdolesMI',
#  'https://www.youtube.com/watch?v=WDkg3h8PCVU',
#  'https://www.youtube.com/watch?v=QUYLG94VWb4',
#  'https://www.youtube.com/watch?v=5MtfYjLjyGg',
#  'https://www.youtube.com/watch?v=vumMdSybdQg',
#  'https://www.youtube.com/watch?v=-oD7B7oiBtw',
#  'https://www.youtube.com/watch?v=wQ1CWUWivjQ',
#  'https://www.youtube.com/watch?v=PQIq4BUw_Hs',
#  'https://www.youtube.com/watch?v=rV0vcfT8WQs',
#  'https://www.youtube.com/watch?v=Yn60wQvKhaY',
#  'https://www.youtube.com/watch?v=Gp_RnJcb8Ig',
# ...

# %%
#getting titles
titles=[i.text for i in browser.find_elements_by_id('video-title')]
titles
# Out:
# ['Blind Chicken Wing Taste Test',
#  'Alita: Battle Angel | Official Trailer [HD] | 20th Century FOX',
#  "Sara Haines Announces She's Leaving 'The View' To Host 'GMA Day'",
#  "5 things you need to know before tonight's Raw: July 23, 2018",
#  'Small airplane CATASTROPHIC ENGINE FAILURE in the middle of nowhere - The Story',
#  'Engine Failure Follow Up and Oshkosh 2018',
#  'Airstrip Home Build Update 3 - Factory Visit and Picking Finishes',
#  'This Kitfox is a BEAST! - Rotax 915iS 141hp Turbocharged Fuel Injected Monster',
#  '',
#  'Game Theory: We Were Right ALL ALONG! (FNAF Ultimate Custom Night)',
#  'Aquaman - Official Trailer 1',
#  'SIDEMEN BOWLING (GONE WRONG)',
#  'MY AMAZON FAVORITES! Fitness, Lifestyle & Random MUST HAVES! | Casey Holmes',
#  'What is Dog Water Fountain?',
#  'SHAZAM! Trailer (2019)',
#  'IS DRIFT EVIL IN FORTNITE?! * SEASON 5 *Fortnite Short Film',
#  'It’s BIG...it’s BLUE...it’s NEW!',
#  'PEOPLE WHO THOUGHT THEY WERE SMART',
# ...

# %% [markdown]
# #code showing that getting duration cannot be implemented using selenium, so I switched to beautiful soup for this particular task
#  [i.text for i in  browser.find_elements_by_xpath('//span[@class="style-scope ytd-thumbnail-overlay-time-status-renderer"]')]

# %%
#getting duration and cleaning data
response = browser.page_source
page = BeautifulSoup(response,"html.parser")
duration=[i.get_text().replace("\n", "").strip() for i in  page.find_all("span", class_="style-scope ytd-thumbnail-overlay-time-status-renderer")]
duration
# Out:
# ['14:29',
#  '2:37',
#  '4:55',
#  '1:31',
#  '26:27',
#  '11:28',
#  '8:23',
#  '9:16',
#  '3:46',
#  '18:32',
#  '2:26',
#  '12:36',
#  '19:36',
#  '10:27',
#  '3:14',
#  '18:44',
#  '7:02',
#  '12:45',
#  '10:02',
#  '1:54',
#  '2:53',
#  '19:24',
#  '10:02',
#  '12:32',
#  '5:17',
#  '6:21',
#  '10:06',
#  '7:57',
#  '1:18',
#  '5:05',
#  '35:44',
#  '10:37',
#  '10:10',
#  '14:20',
#  '2:52',
#  '7:54',
#  '8:49',
#  '5:41:00',
#  '1:31',
#  '2:42',
#  '4:42',
#  '4:01',
#  '26:42',
#  '3:23',
#  '4:09',
#  '14:07',
#  '0:51',
#  '5:50',
#  '12:19',
#  '3:18',
#  '10:20',
#  '5:37',
#  '6:31',
#  '5:29',
#  '12:07',
#  '8:26',
#  '14:50',
#  '9:25',
#  '1:07',
#  '2:31',
#  '16:58',
#  '18:46',
#  '3:32',
#  '10:59',
#  '10:20',
#  '3:11',
#  '15:11',
#  '2:30',
#  '2:47',
#  '12:50',
#  '4:24',
#  '2:03',
#  '6:31',
#  '19:04']

# %%
#getting views and cleaning data
#regex find meaning:find everything with no white space "\S" then numbers then everything ".+" and str(views) 
all_labels=[i.get_attribute('aria-label') for i in browser.find_elements_by_css_selector('a#video-title')]
view=[i[0] for i in [re.findall("\S+[0-9]+.views",i) for i in all_labels]] 
views=[i.replace("views", "")for i in view]
views
# Out:
# ['1,304,914 ',
#  '2,504,409 ',
#  '373,362 ',
#  '254,958 ',
#  '211,115 ',
#  '56,890 ',
#  '47,877 ',
#  '203,375 ',
#  '18,444 ',
#  '3,674,261 ',
#  '22,855,117 ',
#  '2,612,985 ',
#  '176,109 ',
#  '637,227 ',
#  '10,875,699 ',
#  '961,406 ',
#  '616,598 ',
#  '1,221,200 ',
#  '1,637,943 ',
#  '1,500,070 ',
#  '7,357,024 ',
#  '3,871,008 ',
#  '281,602 ',
#  '876,423 ',
#  '464,313 ',
#  '957,048 ',
#  '2,520,974 ',
#  '1,064,010 ',
#  '1,769,726 ',
#  '1,633,596 ',
#  '769,123 ',
#  '1,913,270 ',
#  '981,403 ',
#  '250,609 ',
#  '18,972,631 ',
#  '624,256 ',
#  '755,182 ',
#  '906,786 ',
#  '6,592,394 ',
#  '5,142,712 ',
#  '742,140 ',
#  '9,382,653 ',
#  '1,140,884 ',
#  '8,948,094 ',
#  '11,806,680 ',
#  '2,548,613 ',
#  '1,051,532 ',
#  '148,317 ',
#  '349,643 ',
#  '175,836 ',
#  '301,658 ',
#  '977,714 ',
#  '2,980,312 ',
#  '1,604,878 ',
#  '20,973,716 ',
#  '3,107,206 ',
#  '1,528,383 ',
#  '2,026,780 ',
#  '7,498,558 ',
#  '8,256,717 ',
#  '9,800,209 ',
# ...

# %%
#getting usernames
username=[i.text for i in browser.find_elements_by_xpath('//*[@id="byline"]/a')]
username
# Out:
# ['Good Mythical Morning',
#  '20th Century Fox',
#  'The View',
#  'WWE',
#  'Trent Palmer',
#  'Trent Palmer',
#  'Trent Palmer',
#  'Trent Palmer',
#  '',
#  'The Game Theorists',
#  'Warner Bros. Pictures',
#  'Sidemen',
#  'Casey Holmes',
#  'CrazyRussianHacker',
#  'FilmSelect Trailer',
#  'Little Lizard - Fortnite',
#  'Brave Wilderness',
#  'SSSniperWolf',
#  'Dobre Brothers',
#  'Netflix',
#  'Universal Pictures',
#  'Lachlan',
#  'The Office US',
#  'Mr. Nightmare',
#  'BuzzFeedVideo',
#  'Fox News',
#  'nigahiga',
#  'Guava Juice',
#  'Meet Arnold',
#  'DC',
#  'KathleenLights',
#  'How Ridiculous',
#  'FBE',
#  'Christen Dominique',
#  'Anitta',
#  'Jess Conte',
#  'The Late Show with Stephen Colbert',
#  'Fortnite',
#  'IGN',
#  'Star Wars',
#  'Vox',
#  'TheOdd1sOut',
#  'Jaclyn Hill',
#  'Bebe Rexha',
#  'Troye Sivan',
#  'CinemaSins',
#  'Doctor Who',
#  'Jacob Lee',
#  'Draw with Jazza',
#  'Passenger',
#  'SuperCarlinBrothers',
#  'shgurr',
#  'Hannah Stocking',
# ...

# %%
#making the obtained data a pandas dataframe to sum up
final_selenium=pd.DataFrame(list(zip(titles,urls,duration, username, views)), columns=['Title','Url', 'Duration', 'Username', 'Views'])
final_selenium
# Out:
#                                                 Title  \
# 0                       Blind Chicken Wing Taste Test
# 1   Alita: Battle Angel | Official Trailer [HD] | ...
# 2   Sara Haines Announces She's Leaving 'The View'...
# 3   5 things you need to know before tonight's Raw...
# 4   Small airplane CATASTROPHIC ENGINE FAILURE in ...
# 5           Engine Failure Follow Up and Oshkosh 2018
# 6   Airstrip Home Build Update 3 - Factory Visit a...
# 7   This Kitfox is a BEAST! - Rotax 915iS 141hp Tu...
# 8
# 9   Game Theory: We Were Right ALL ALONG! (FNAF Ul...
# 10                       Aquaman - Official Trailer 1
# 11                       SIDEMEN BOWLING (GONE WRONG)
# 12  MY AMAZON FAVORITES! Fitness, Lifestyle & Rand...
# 13                        What is Dog Water Fountain?
# 14                             SHAZAM! Trailer (2019)
# 15  IS DRIFT EVIL IN FORTNITE?! * SEASON 5 *Fortni...
# 16                   It’s BIG...it’s BLUE...it’s NEW!
# ...

# %%
#closing the browser
browser.close()

# %%
#Saving to csv with no separate indexing and using colnames as headers

final_selenium.to_csv('final_selenium.csv',index=False, header=True)
#opening csv to verify everything is saved correctly
data=pd.read_csv('final_selenium.csv')
pprint(data.head(5))
# Out:
#                                                Title  \
# 0                      Blind Chicken Wing Taste Test
# 1  Alita: Battle Angel | Official Trailer [HD] | ...
# 2  Sara Haines Announces She's Leaving 'The View'...
# 3  5 things you need to know before tonight's Raw...
# 4  Small airplane CATASTROPHIC ENGINE FAILURE in ...
#
#                                            Url Duration  \
# 0  https://www.youtube.com/watch?v=MBPdKxlazD0    14:29
# 1  https://www.youtube.com/watch?v=w7pYhpJaJW8     2:37
# 2  https://www.youtube.com/watch?v=f3uVr2bZKUU     4:55
# 3  https://www.youtube.com/watch?v=tgBHu2D66Rg     1:31
# 4  https://www.youtube.com/watch?v=YUAIFQfgH_s    26:27
#
#                 Username       Views
# 0  Good Mythical Morning  1,304,914
# 1       20th Century Fox  2,504,409
# 2               The View    373,362
# 3                    WWE    254,958
# 4           Trent Palmer    211,115

# %%
#Saving to json file with orient=records to match colnames and values

final_selenium.to_json('final_selenium.json', orient="records") 
#opening json to read it
with open('final_selenium.json','r') as final_selenium:
    selenium_json = json.load(final_selenium)
pprint(selenium_json)
# Out:
# [{'Duration': '14:29',
#   'Title': 'Blind Chicken Wing Taste Test',
#   'Url': 'https://www.youtube.com/watch?v=MBPdKxlazD0',
#   'Username': 'Good Mythical Morning',
#   'Views': '1,304,914 '},
#  {'Duration': '2:37',
#   'Title': 'Alita: Battle Angel | Official Trailer [HD] | 20th Century FOX',
#   'Url': 'https://www.youtube.com/watch?v=w7pYhpJaJW8',
#   'Username': '20th Century Fox',
#   'Views': '2,504,409 '},
#  {'Duration': '4:55',
#   'Title': "Sara Haines Announces She's Leaving 'The View' To Host 'GMA Day'",
#   'Url': 'https://www.youtube.com/watch?v=f3uVr2bZKUU',
#   'Username': 'The View',
#   'Views': '373,362 '},
#  {'Duration': '1:31',
#   'Title': "5 things you need to know before tonight's Raw: July 23, 2018",
#   'Url': 'https://www.youtube.com/watch?v=tgBHu2D66Rg',
#   'Username': 'WWE',
#   'Views': '254,958 '},
#  {'Duration': '26:27',
#   'Title': 'Small airplane CATASTROPHIC ENGINE FAILURE in the middle of '
#            'nowhere - The Story',
# ...
